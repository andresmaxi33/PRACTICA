# %%
#==== PUNTO 4A ======
import sys
from pathlib import Path

# Agregar la carpeta src al path para poder importar
sys.path.append(str(Path("..").resolve() / "src"))

from ejercicio4 import inicio_registro

#Hacemos un registro de iadiza
registro_iadiza = inicio_registro("iadiza")
print("Registro iadiza: " , registro_iadiza)

#uno de xenocanto
registro_xenocanto = inicio_registro("xenocanto")
print("Registro xenocanto: " , registro_xenocanto)

#y uno de inaturalist
registro_inaturalist = inicio_registro("inaturalist")
print("Registro inaturalist: " , registro_inaturalist)

# %%
#====== PUNTO 4B =======
import sys
from pathlib import Path

# Agregar la carpeta src al path para poder importar
sys.path.append(str(Path("..").resolve() / "src"))

from ejercicio4 import inicializar_registro

#Lista de columnas para completar el registro, ejemplo
columnas = ["scientificName", "eventDate", "decimalLatitude", "decimalLongitude"]
#creamos un registro
nuevo_registro = inicializar_registro(columnas)

print (nuevo_registro)

# %%
#====== PUNTO 4C ========
import sys
from pathlib import Path

# Agregar la carpeta src al path para poder importar
sys.path.append(str(Path("..").resolve() / "src"))

from ejercicio4 import agrupar_validaciones

# Registro válido
registro_valido = {
    "decimalLatitude": "-34.6",
    "decimalLongitude": "-58.4",
    "eventDate": "2020-05-01",
    "countryCode": "AR",
    "coordinateUncertaintyInMeters": "50"
}

print("Registro válido:", agrupar_validaciones(registro_valido))

# Registro inválido
registro_invalido = {
    "decimalLatitude": "-95",   # fuera de rango
    "decimalLongitude": "-200", # fuera de rango
    "eventDate": "2030-01-01",  # fecha futura
    "countryCode": "ZZ",        # inválido
    "coordinateUncertaintyInMeters": "-10"  # negativa
}

print("Registro inválido:", agrupar_validaciones(registro_invalido))

# %%
#======== PUNTO 4D =========
import sys
from pathlib import Path

# Agregar la carpeta src al path para poder importar
sys.path.append(str(Path("..").resolve() / "src"))

from ejercicio4 import preparar_para_csv

#Prepararmos registros para probar el funcinamiento de 4d
registro_iadiza = {"scientificName": "", "decimalLatitude": "", "decimalLongitude": ""}
registro_xenocanto = {"scientificName": "", "decimalLatitude": "", "decimalLongitude": ""}
registro_inaturalist = {"scientific_name": "", "latitude": "", "longitude": ""}

#Asignamos ID
print ("Registro iadiza: ", preparar_para_csv(registro_iadiza , "iadiza"))
print ("Registro xenocanto: ", preparar_para_csv(registro_xenocanto, "xenocanto"))
print ("Registro inaturalist: ", preparar_para_csv(registro_inaturalist, "inaturalist"))

# %%
#====== PUNTO 4F =========
import sys
from pathlib import Path

# Agregar la carpeta src al path para poder importar
sys.path.append(str(Path("..").resolve() / "src"))

from ejercicio4 import agregar_registro

#no se pone el valor de la carpeta porque por defecto ya tiene processed_datasets
agregar_registro(1, "iadiza")

# %%
#====== PUNTO 4G =======
import sys
from pathlib import Path

#Agregar la carpeta src al path para poder importar
sys.path.append(str(Path("..").resolve() / "src"))

from ejercicio4 import agregar_multiples_registros

#Insertamos 3 registros en iadiza
agregar_multiples_registros(1, "iadiza", 3)
