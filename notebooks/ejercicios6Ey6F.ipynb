# %%
import sys
sys.path.append("../src")

# %%
from eliminacion import sanitizar_dataset

# %%
# Este bloque ejecuta la sanitización del dataset.
# Se eliminan registros inválidos según criterios definidos
# y se genera un nuevo dataset limpio junto con un reporte
# de cantidad, porcentaje y motivos de eliminación.

# %%
ruta_entrada = "../raw_datasets/iadiza/occurrence.txt"
ruta_salida = "../processed_datasets/iadiza_limpio.txt"

sanitizar_dataset(ruta_entrada, ruta_salida)
# Out:
# Sanitización completada
# Registros totales: 2370
# Registros eliminados: 0
# Porcentaje eliminado: 0.00%
# Motivos detectados:
# - latitud_invalida: 0
# - longitud_invalida: 0
# - fecha_invalida: 2370
# - nombre_cientifico_vacio: 0
