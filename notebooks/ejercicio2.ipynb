# %%
import sys
from pathlib import Path

# Agregar la carpeta src al path para poder importar
sys.path.append(str(Path("..").resolve() / "src"))

# Importar funciones
from cargardataset import seleccionar_y_cargar_dataset
from ejercicio2 import *

# Seleccionar dataset (te va a pedir 1, 2 o 3)
dataset = seleccionar_y_cargar_dataset()

# %%
ejercicio2A(dataset)

# %%
ejercicio2B(dataset)

# %%
ejercicio2C(dataset)

# %%
ejercicio2D(dataset)

# %%
ejercicio2E(dataset)

# %%
ejercicio2F(dataset)

# %%
ejercicio2G(dataset, 'scientificName')

# %%
ejercicio2H(dataset, 'countryCode')

# %%
ejercicio2I(dataset, 'catalogNumber','numeric')

# %%
ejercicio2J(dataset)
